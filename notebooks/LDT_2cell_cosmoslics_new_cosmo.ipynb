# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

# Add the modules/ folder to the Python path
module_path = os.path.abspath(os.path.join('..', 'modules'))
if module_path not in sys.path:
    sys.path.append(module_path)

from imports import *
# Out:
# 2025-06-03 15:19:59,523 - INFO - Common imports loading...
# Executing common imports from imports.py...

# %%
cosmotable = np.loadtxt('lhs_cosmo_samples_halofit.dat')
cosmotable_om = cosmotable[:,0]
cosmotable_h = cosmotable[:,1]
cosmotable_w0 = cosmotable[:,2]
cosmotable_sig8 =  cosmotable[:,3]
# cosmotable_oc = cosmotable[:,5]

# Define parameter bounds based on min and max values
param_bounds = np.array([
    [np.min(cosmotable_om), cosmotable_om.max()],
    [cosmotable_h.min(), cosmotable_h.max()],
    [cosmotable_w0.min(), cosmotable_w0.max()],
    [cosmotable_sig8.min(), cosmotable_sig8.max()],
    # [cosmotable_oc.min(), cosmotable_oc.max()]
])

print(param_bounds)
# Number of samples (adjust as needed)
num_samples = 100

# Generate Latin Hypercube Samples
sampler = qmc.LatinHypercube(d=param_bounds.shape[0])
lh_samples = sampler.random(n=num_samples)

# Scale samples to the parameter bounds
lh_scaled = qmc.scale(lh_samples, param_bounds[:, 0], param_bounds[:, 1])

# Convert to a structured array or DataFrame if needed

lh_df = pd.DataFrame(cosmotable[:,:], columns=["Om", "h", "w0", "sig8"])

# Display or save results
# print(lh_df)  # Print first few samples

cosmotable
lh_df
# Out:
# [[ 0.207638  0.392847]
#  [ 0.601937  0.798149]
#  [-1.390785 -0.616471]
#  [ 0.608328  0.8927  ]]
#           Om         h        w0      sig8
# 0   0.350144  0.707418 -1.216086  0.892700
# 1   0.387051  0.787803 -1.096119  0.824871
# 2   0.327102  0.781053 -0.836081  0.673094
# 3   0.339554  0.736514 -1.302878  0.849208
# 4   0.293866  0.620079 -0.616471  0.752039
# 5   0.229786  0.718291 -0.769299  0.814115
# 6   0.274505  0.609077 -1.011120  0.793373
# 7   0.309787  0.774507 -1.182791  0.764144
# 8   0.265733  0.735885 -1.137573  0.656508
# 9   0.371088  0.664167 -0.656677  0.623814
# 10  0.361706  0.679025 -1.323622  0.687689
# 11  0.287887  0.699794 -0.718768  0.882621
# 12  0.214369  0.753986 -1.065439  0.706760
# 13  0.251592  0.641868 -0.894702  0.736079
# 14  0.239130  0.601937 -1.390785  0.635800
# 15  0.312440  0.749752 -0.881450  0.866692
# 16  0.303694  0.726119 -1.028754  0.830741
# 17  0.392847  0.638025 -0.667366  0.642034
# 18  0.334238  0.681975 -1.355361  0.725907
# 19  0.216615  0.689266 -0.977228  0.863609
# 20  0.378551  0.631479 -1.246308  0.781670
# 21  0.207638  0.798149 -0.820653  0.770031
# 22  0.353935  0.650249 -0.925739  0.669671
# 23  0.247434  0.761859 -0.740804  0.708514
# 24  0.258033  0.661721 -1.148784  0.608328

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1,2,1)
# Plot empty or invisible scatter just to define the plot area
plt.scatter(lh_df["Om"], lh_df["h"], color='white')  # optional background points

# Annotate with serial numbers as "markers"
for i, row in lh_df.iterrows():
    # if i==9 or i==14 or i==18:
    #     color='red'
    # else:
    color='blue'
    plt.text(row["Om"], row["h"], str(i), fontsize=8, color=color, ha='center', va='center')

plt.xlabel("Omega_m")
plt.ylabel("h")
plt.title("Scatter plot with serial number as marker")
plt.grid(True)

plt.subplot(1,2,2)
# Plot empty or invisible scatter just to define the plot area
plt.scatter(lh_df["w0"], lh_df["sig8"], color='white')  # optional background points

# Annotate with serial numbers as "markers"
for i, row in lh_df.iterrows():
    # if i==9 or i==14 or i==18:
    #     color='red'
    # else:
    color='blue'
    plt.text(row["w0"], row["sig8"], str(i), fontsize=8, color=color, ha='center', va='center')

plt.xlabel("w0")
plt.ylabel("sig8")
plt.title("Scatter plot with serial number as marker")
plt.grid(True)
plt.show()

# %%
theta1_arcmin = 15.0  # Use a descriptive name
R_pixels = int(theta1_arcmin / 0.5) #0.5 arcmin/pixel resolution
print(f"Filter radius in pixels: {R_pixels}")

edges = np.linspace(-0.06, 0.06, 201)
centers = (edges[1:] + edges[:-1]) / 2
snr = np.linspace(-10, 10, 500) # Define SNR range for output interpolation

# Source redshift - can be single value or list depending on analysis needs
zs_source = 1.852 #1.134 # For this specific loop structure

# Path to n(z) file for the relevant bin
nz_file = "/feynman/work/dap/lcs/vt272285/LDT_2cell_l1_norm_recheck/nz_arrays_bin5.npy" 

# Parameters for calculations
kmin_pk = -4 # kmin for power spectrum calculation
kmax_pk = 0.2  # kmax for power spectrum calculation 
n_lensing_planes = 7 # Number of lensing planes

# --- Simulation Volume (Optional) ---
# Set to a float value in (Mpc/h)^3 if cosmic variance noise is desired in P(k)
simulation_volume = 1e7
variability = False

# --- Data Storage ---
l1_prediction_list = []
sigmasq_prediction_list = []
l1_simulation_list = []
l1_simulation_errorbars_list = []
simulation_pdf_list = []

# --- Plotting Setup ---
fig, axs = plt.subplots(1, 2, figsize=(25, 15), dpi=100, gridspec_kw={'width_ratios': [2, 1]})
# 
# --- Main Loop ---
# Loop directly over the desired cosmology index (or indices)

filter_type = 'tophat'
variances = []
l1_prediction_list = []

for cosmo_index_to_run in range(11,25):
    print(f"--- Running for Cosmology Index: {cosmo_index_to_run} ---")

    # --- Theoretical Prediction ---
    # 1. Get Cosmology Parameters from lh_df
    h = lh_df['h'][cosmo_index_to_run]
    Om = lh_df['Om'][cosmo_index_to_run]
    Ob = 0.0473
    sig8 = lh_df['sig8'][cosmo_index_to_run]
    w0 = lh_df['w0'][cosmo_index_to_run]
    wa = 0. # Assuming wa=0 based on original code
    Oc = Om - Ob # Calculate Ob consistently
    # Other fixed parameters from original code
    H0 = 100.0 * h # H0 in km/s/Mpc
    ns = 0.963
    mnu = 0.0

    print("Cosmological Parameters:")
    print(f"  h={h:.4f}, Om={Om:.4f}, Oc={Oc:.4f}, Ob={Ob:.4f}, sigma8={sig8:.4f}, w0={w0:.4f}, wa={wa:.4f}")

    for times in range(1):
        # 2. Initialize Cosmology
        print("Initializing Cosmology...for iteration ", times)
        cosmo = Cosmology_function(
            h=h, H0=H0, Ob=Ob, Oc=Oc, mnu=mnu, ns=ns, zs=zs_source, 
            w=w0, wa=wa, kmin=kmin_pk, kmax=kmax_pk, nz_file=nz_file, sigma8=sig8 
        )

        # 3. Calculate Geometric Quantities (Plane distances, weights)
        print("Calculating lensing geometry...")
        chi_source = cosmo.get_chi(zs_source)
        chis = np.linspace(0.3, chi_source - 5, n_lensing_planes) # Setup lensing planes
        dchis = np.ones(len(chis)) * (chis[1] - chis[0]) / 2 # Differential comoving distances
        dchis[1:-1] *= 2.

        if nz_file is not None:
            z_array, lensing_weight = cosmo.get_lensing_weight_array_nz(chis)
        else:
            # Need chi_source if using single source plane
            z_array, lensing_weight = cosmo.get_lensing_weight_array(chis, chi_source) 

        print(f"  Source Redshift: {zs_source}, Comoving Distance: {chi_source:.2f} Mpc/h")
        print(f"  Number of lensing planes: {n_lensing_planes}")

        # Determine appropriate redshift range based on z_array or zs_source
        max_crit_z = min(zs_source * 0.6, np.max(z_array)) if len(z_array)>0 else zs_source*0.95 # Avoid edge
        crit_point_z = np.linspace(0.001, zs_source * 0.1, 5) 

        # 4. Initialize Variance (this will compute P(k) internally)
        print("Initializing Variance and P(k)...")
        variance = Variance(
            cosmo=cosmo, 
            z_values=z_array,
            z_values_critical = crit_point_z,
            filter_type = filter_type,
            variability=variability, 
            delta_A0=.7 
        )

        # 5. Initialize VariablesGenerator (this calculates sigmasq_map)
        print("Initializing VariablesGenerator...")
        variables = VariablesGenerator(
            cosmo=cosmo, 
            variance=variance, 
            zs=zs_source, 
            theta1=theta1_arcmin, 
            nz_file=nz_file, 
            nplanes=n_lensing_planes,
            chis=chis, 
            dchis=dchis, 
            z_array=z_array, 
            lensing_weight=lensing_weight
        )

        variables.recal_value = 1.0 
        # If recalibration based on simulation variance is desired:
        print(f"Theoretical Map Variance (sigmasq_map): {variables.sigmasq_map:.4g}")
        print(f"Recalibration Value Set To: {variables.recal_value}") 
        variances.append(variables.sigmasq_map)
        
        # 6. Find Critical Points
        print("Finding critical points...")
        criticalpoints = CriticalPointsFinder(variables, ngrid=120, plot=False) 
        critical_values_list = []
        print(f"  Redshift range for critical points: {crit_point_z}")
        for z_crit in crit_point_z:
            crit_vals = criticalpoints.get_critical_points(z_crit)
            # crit_vals = criticalpoints.find_critical_points_grid_scipy(z_crit, deld=1e-4, initial_guesses=[(-0.5, -0.5), (.5, .5)])
            print(f"  Critical points for z={z_crit:.7f}: {crit_vals}")
            if crit_vals is not None and len(crit_vals) >= 2:
                critical_values_list.append(crit_vals[:2])
            if crit_vals is not None and len(crit_vals) == 1:
                critical_values_list.append([np.nan,crit_vals[0]]) 
        if not critical_values_list:
            print("  Warning: No critical points found in the specified redshift range.")
            smallest_pair_info = None
        else:
            critical_values_array = np.array(critical_values_list)
            flat_values = []
            for item in critical_values_list:
                if isinstance(item, (np.ndarray, list)):
                    flat_values.extend(np.ravel(item))
                else:
                    flat_values.append(item)

            flat_values = np.array(flat_values)

            # Remove NaNs if any
            flat_values = flat_values[~np.isnan(flat_values)]

            # Smallest positive value
            positive_values = flat_values[flat_values > 0]
            smallest_positive = np.min(positive_values) if positive_values.size > 0 else None

            # Largest negative value
            negative_values = flat_values[flat_values < 0]
            largest_negative = np.max(negative_values) if negative_values.size > 0 else None

            print("Smallest positive value:", smallest_positive)
            print("Largest negative value:", largest_negative)
            print("Smallest distance pair of critical points:", smallest_positive, largest_negative)

        # 7. Compute PDF
        print("Computing PDF...")
        # Set lambda range based on critical points if found
        if smallest_positive and largest_negative is not None:
            # Add buffer around the critical lambda values
            lambda_min = largest_negative + 0 # Adjust buffer as needed
            lambda_max = smallest_positive - 0 # Adjust buffer as needed
            variables.lambdas = np.linspace(lambda_min, lambda_max, 20) # Use dynamic range
            print(f"  Using lambda range: [{lambda_min:.2f}, {lambda_max:.2f}]")
        else:
            # Fallback lambda range if critical points not found or invalid
            variables.lambdas = np.linspace(-80, 200, 100) 
            print("  Warning: Using fallback lambda range.")
        
        
        # if 0 < cosmo_index_to_run < 5:
        #     variables.lambdas = np.linspace(-70, 350, 20) 
        # elif cosmo_index_to_run == 0:
        #     variables.lambdas = np.linspace(-100, 450, 20) 
        # elif 5 <= cosmo_index_to_run < 9:
        #     variables.lambdas = np.linspace(-70, 310, 20) 
        # elif cosmo_index_to_run == 9:
        #     variables.lambdas = np.linspace(-800, 1450, 20)
        # elif 10<= cosmo_index_to_run < 15 and cosmo_index_to_run != 12:
        #     variables.lambdas = np.linspace(-110, 500, 20) #12
        # elif cosmo_index_to_run == 12:
        #     variables.lambdas = np.linspace(-700, 1600, 20)
        # elif cosmo_index_to_run == 15:
        #     variables.lambdas = np.linspace(-250, 670, 20)
        # elif 15 < cosmo_index_to_run < 20:
        #     variables.lambdas = np.linspace(-100, 350, 20) #15
        # elif 20 <= cosmo_index_to_run < 25:
        #     variables.lambdas = np.linspace(-110, 500, 20)
        
        computed_PDF = computePDF(variables, plot_scgf=False) # Pass the updated variables object
        pdf_values, kappa_values = computed_PDF.pdf_values, computed_PDF.kappa_values

        # 8. Calculate Predicted L1 norm
        print("Calculating predicted L1 norm...")
        # pdf_spline = CubicSpline(kappa_values, pdf_values) 
        l1_pred_values = get_l1_from_pdf(pdf_values, kappa_values)

        # Store predictions
        sigmasq_prediction_list.append(variables.sigmasq_map)
        l1_prediction_list.append(l1_pred_values)
        
        # Plotting L1 comparison
        # fig, axs = plt.subplots(1, 2, figsize=(25, 15), dpi=100, gridspec_kw={'width_ratios': [2, 1]})
        colour = list(np.random.choice(range(256), size=3) / 255) # Random color for this run
        plot_scale_factor = 1.0 # 
        axs[0].plot(kappa_values, l1_pred_values * plot_scale_factor, alpha=1., c=colour) 
        # axs[0].plot(kappa_values, pdf_values , alpha=1., c=colour, lw=4) 
        
        # Calculate moments from predicted PDF
        pred_stats = get_moments(kappa_values, pdf_values)
        pred_mean, pred_var, pred_skew, pred_kurt, pred_norm = pred_stats
        print(f"Prediction PDF Moments: Mean={pred_mean:.4g}, Variance={pred_var:.4g}, Skewness={pred_skew:.4g}, Kurtosis={pred_kurt:.4g}")

        # --- Comparison and Plotting ---
        print("\n--- Comparison ---")
        comparison_data = {
            "Metric": ["Mean", "Variance", "Skewness", "Kurtosis", "Norm"],
            "Prediction PDF": [f"{v:.4g}" for v in pred_stats],
            # "Simulation Avg PDF": [f"{v:.4g}" for v in sim_stats],
        }
        df_comp = pd.DataFrame(comparison_data)
        print(df_comp)
        print("-----------------\n")
    
        axs[1].scatter(1, 25 - cosmo_index_to_run, color=colour) # Adjust y-positioning as needed
        axs[1].annotate(f"Cosmo {cosmo_index_to_run}", (1, 25 - cosmo_index_to_run), xytext=(5, 0), textcoords='offset points', va='center')

# --- Final Plot Formatting ---
# axs[0].hlines(0, np.min(x_axis_vals), np.max(x_axis_vals), color='gray', ls='--')
# axs[0].axhspan(-0.05 * plot_scale_factor, 0.05 * plot_scale_factor, color='gray', alpha=0.2) # Adjust span based on plot scale
axs[0].set_xlabel(r'SNR = $\kappa$', size=14) 
axs[0].set_ylabel(r'$\ell_1(\kappa)$ Scaled', size=14) # Adjust label if scale factor changes
# Set xlim based on plotted range, e.g., +/- 3 sigma
# xlim_range = 5 * pred_stdev 
# axs[0].set_xlim(-5, 5) 



# ylim can be set dynamically or fixed
# axs[0].set_ylim(-0.1 * plot_scale_factor, np.nanmax(l1_pred_on_snr * plot_scale_factor) * 1.1) 
axs[0].grid(True, which='both', axis='both')
# axs[0].legend() # Add legend to the main plot

# Format the second axes panel (cosmology labels)
axs[1].set_xticks([])
axs[1].set_yticks([])
axs[1].set_xticklabels([])
axs[1].set_yticklabels([])
axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
axs[1].spines['bottom'].set_visible(False)
axs[1].spines['left'].set_visible(False)
axs[1].set_title("Cosmology Index")

plt.tight_layout()
plt.show()
# Out:
# Filter radius in pixels: 30
# --- Running for Cosmology Index: 11 ---
# Cosmological Parameters:
#   h=0.6998, Om=0.2879, Oc=0.2406, Ob=0.0473, sigma8=0.8826, w0=-0.7188, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3275.27 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 2.7027125601806496e-05
# Theoretical Map Variance (sigmasq_map): 2.703e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-641.13749756]
#   Critical points for z=0.0470500: [-641.13749756]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [ 885.57483   -223.5415395]
#   Critical points for z=0.0931000: [ 885.57483   -223.5415395]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [  396.8543917   -165.90192659 -1966.49959109]
#   Critical points for z=0.1391500: [  396.8543917   -165.90192659 -1966.49959109]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 330.72809541 -185.37841321]
#   Critical points for z=0.1852000: [ 330.72809541 -185.37841321]
# Smallest positive value: 330.7280954100458
# Largest negative value: -165.90192658530475
# Smallest distance pair of critical points: 330.7280954100458 -165.90192658530475
# Computing PDF...
#   Using lambda range: [-165.90, 330.73]
# the coeffs are [ 1.02703489e-07 -2.12702549e-07  2.01928865e-06 -6.35818909e-06
#   8.04418083e-05 -2.51159611e-04  5.19875412e-03  1.56479487e-09]
# 2.7027044391022888e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=2.465e-08, Variance=2.703e-05, Skewness=-55.71, Kurtosis=0.4811
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      2.465e-08
# 1  Variance      2.703e-05
# 2  Skewness         -55.71
# 3  Kurtosis         0.4811
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 12 ---
# Cosmological Parameters:
#   h=0.7540, Om=0.2144, Oc=0.1671, Ob=0.0473, sigma8=0.7068, w0=-1.0654, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3820.58 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.3539237117550084e-05
# Theoretical Map Variance (sigmasq_map): 1.354e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-1444.4703507]
#   Critical points for z=0.0470500: [-1444.4703507]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-502.55165076]
#   Critical points for z=0.0931000: [-502.55165076]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 796.74222376 -408.80280886]
#   Critical points for z=0.1391500: [ 796.74222376 -408.80280886]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 757.31898079 -448.98383066]
#   Critical points for z=0.1852000: [ 757.31898079 -448.98383066]
# Smallest positive value: 757.3189807949019
# Largest negative value: -408.80280886308753
# Smallest distance pair of critical points: 757.3189807949019 -408.80280886308753
# Computing PDF...
#   Using lambda range: [-408.80, 757.32]
# the coeffs are [ 1.84491259e-08 -1.19075146e-07  1.02031034e-07 -1.98426149e-07
#   2.02984165e-05 -9.60926573e-05  3.67946887e-03  6.60038318e-08]
# 1.3538491183716094e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=6.6e-08, Variance=1.354e-05, Skewness=-42.59, Kurtosis=0.1651
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean        6.6e-08
# 1  Variance      1.354e-05
# 2  Skewness         -42.59
# 3  Kurtosis         0.1651
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 13 ---
# Cosmological Parameters:
#   h=0.6419, Om=0.2516, Oc=0.2043, Ob=0.0473, sigma8=0.7361, w0=-0.8947, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3529.66 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 9.676419824644496e-06
# Theoretical Map Variance (sigmasq_map): 9.676e-06
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-1313.0016812  -1385.81905157 -1447.71794407]
#   Critical points for z=0.0470500: [-1313.0016812  -1385.81905157 -1447.71794407]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-512.49940947]
#   Critical points for z=0.0931000: [-512.49940947]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 870.71505864 -346.01556279]
#   Critical points for z=0.1391500: [ 870.71505864 -346.01556279]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 645.30200942 -355.96273145]
#   Critical points for z=0.1852000: [ 645.30200942 -355.96273145]
# Smallest positive value: 645.3020094237737
# Largest negative value: -346.0155627908973
# Smallest distance pair of critical points: 645.3020094237737 -346.0155627908973
# Computing PDF...
#   Using lambda range: [-346.02, 645.30]
# the coeffs are [ 9.81008784e-08 -1.59317703e-08  3.35608813e-08 -1.85322229e-06
#   2.94633405e-05 -1.12224792e-04  3.11055895e-03 -2.51202529e-08]
# 9.675576962496391e-06
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=-2.512e-08, Variance=9.676e-06, Skewness=-69.59, Kurtosis=0.2898
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean     -2.512e-08
# 1  Variance      9.676e-06
# 2  Skewness         -69.59
# 3  Kurtosis         0.2898
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 14 ---
# Cosmological Parameters:
#   h=0.6019, Om=0.2391, Oc=0.1918, Ob=0.0473, sigma8=0.6358, w0=-1.3908, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3950.94 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 4.9894503635502825e-06
# Theoretical Map Variance (sigmasq_map): 4.989e-06
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  []
#   Critical points for z=0.0470500: []
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-998.36956053]
#   Critical points for z=0.0931000: [-998.36956053]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [-628.60390253]
#   Critical points for z=0.1391500: [-628.60390253]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [-612.35351134]
#   Critical points for z=0.1852000: [-612.35351134]
# Smallest positive value: None
# Largest negative value: -612.3535113373367
# Smallest distance pair of critical points: None -612.3535113373367
# Computing PDF...
#   Warning: Using fallback lambda range.
# the coeffs are [-4.99133071e-05  5.31811421e-05 -1.56060511e-05 -1.11439162e-06
#   1.24336723e-05 -5.76062845e-05  2.23369701e-03  4.93080158e-10]
# 4.989402321766492e-06
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=1.91e-06, Variance=5.065e-06, Skewness=49.73, Kurtosis=4.715
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean       1.91e-06
# 1  Variance      5.065e-06
# 2  Skewness          49.73
# 3  Kurtosis          4.715
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 15 ---
# Cosmological Parameters:
#   h=0.7498, Om=0.3124, Oc=0.2651, Ob=0.0473, sigma8=0.8667, w0=-0.8814, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3354.11 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 3.923252295589877e-05
# Theoretical Map Variance (sigmasq_map): 3.923e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-557.25984675]
#   Critical points for z=0.0470500: [-557.25984675]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [ 718.88755824 -206.51243217 -610.21035686 -641.37321659]
#   Critical points for z=0.0931000: [ 718.88755824 -206.51243217 -610.21035686 -641.37321659]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [  345.256313    -162.81141405 -1125.45000793 -1153.57588949
#  -1187.66569505 -1234.94131856]
#   Critical points for z=0.1391500: [  345.256313    -162.81141405 -1125.45000793 -1153.57588949
#  -1187.66569505 -1234.94131856]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 329.50832994 -187.63084826]
#   Critical points for z=0.1852000: [ 329.50832994 -187.63084826]
# Smallest positive value: 329.508329944572
# Largest negative value: -162.81141404551468
# Smallest distance pair of critical points: 329.508329944572 -162.81141404551468
# Computing PDF...
#   Using lambda range: [-162.81, 329.51]
# the coeffs are [ 5.02726050e-08 -1.20864156e-07  1.28375323e-06 -3.54174322e-06
#   7.25825202e-05 -2.57800307e-04  6.26358610e-03  1.84175618e-09]
# 3.9232510879242915e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=1.062e-07, Variance=3.923e-05, Skewness=-39.32, Kurtosis=0.3546
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      1.062e-07
# 1  Variance      3.923e-05
# 2  Skewness         -39.32
# 3  Kurtosis         0.3546
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 16 ---
# Cosmological Parameters:
#   h=0.7261, Om=0.3037, Oc=0.2564, Ob=0.0473, sigma8=0.8307, w0=-1.0288, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3478.88 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 3.080150146871791e-05
# Theoretical Map Variance (sigmasq_map): 3.08e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-673.00897912]
#   Critical points for z=0.0470500: [-673.00897912]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [ 891.81198849 -245.00872374]
#   Critical points for z=0.0931000: [ 891.81198849 -245.00872374]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 415.18958005 -190.77544572]
#   Critical points for z=0.1391500: [ 415.18958005 -190.77544572]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 380.1037442  -217.71767707]
#   Critical points for z=0.1852000: [ 380.1037442  -217.71767707]
# Smallest positive value: 380.1037442004759
# Largest negative value: -190.77544571960735
# Smallest distance pair of critical points: 380.1037442004759 -190.77544571960735
# Computing PDF...
#   Using lambda range: [-190.78, 380.10]
# the coeffs are [ 8.78199133e-08 -5.59008634e-07  8.23235257e-07 -1.35275540e-06
#   5.56994570e-05 -2.10859254e-04  5.54989769e-03  5.51377304e-08]
# 3.0801364393186176e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=6.819e-08, Variance=3.08e-05, Skewness=-41.05, Kurtosis=0.3092
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      6.819e-08
# 1  Variance       3.08e-05
# 2  Skewness         -41.05
# 3  Kurtosis         0.3092
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 17 ---
# Cosmological Parameters:
#   h=0.6380, Om=0.3928, Oc=0.3455, Ob=0.0473, sigma8=0.6420, w0=-0.6674, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3046.90 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.1414367566392926e-05
# Theoretical Map Variance (sigmasq_map): 1.141e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-1348.08257645]
#   Critical points for z=0.0470500: [-1348.08257645]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-483.10852673]
#   Critical points for z=0.0931000: [-483.10852673]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 879.82602649 -330.33452992]
#   Critical points for z=0.1391500: [ 879.82602649 -330.33452992]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 641.25127639 -344.19211395]
#   Critical points for z=0.1852000: [ 641.25127639 -344.19211395]
# Smallest positive value: 641.251276385162
# Largest negative value: -330.3345299244593
# Smallest distance pair of critical points: 641.251276385162 -330.3345299244593
# Computing PDF...
#   Using lambda range: [-330.33, 641.25]
# the coeffs are [-1.00317134e-08 -1.19308791e-08  6.39484972e-07 -2.74699167e-06
#   2.85048924e-05 -1.23372233e-04  3.37852828e-03 -1.32958219e-08]
# 1.141445332874861e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=-1.327e-08, Variance=1.141e-05, Skewness=-64.85, Kurtosis=0.2665
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean     -1.327e-08
# 1  Variance      1.141e-05
# 2  Skewness         -64.85
# 3  Kurtosis         0.2665
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 18 ---
# Cosmological Parameters:
#   h=0.6820, Om=0.3342, Oc=0.2869, Ob=0.0473, sigma8=0.7259, w0=-1.3554, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3551.13 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.9920108024189548e-05
# Theoretical Map Variance (sigmasq_map): 1.992e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-992.11304742]
#   Critical points for z=0.0470500: [-992.11304742]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-357.54568589]
#   Critical points for z=0.0931000: [-357.54568589]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 613.90879074 -268.86939482]
#   Critical points for z=0.1391500: [ 613.90879074 -268.86939482]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 521.02544973 -299.7490727 ]
#   Critical points for z=0.1852000: [ 521.02544973 -299.7490727 ]
# Smallest positive value: 521.0254497282898
# Largest negative value: -268.8693948177867
# Smallest distance pair of critical points: 521.0254497282898 -268.8693948177867
# Computing PDF...
#   Using lambda range: [-268.87, 521.03]
# the coeffs are [-3.71703943e-08  5.03112687e-08  5.98695756e-07 -1.60127241e-06
#   3.21340348e-05 -1.44504442e-04  4.46331823e-03  3.64930945e-09]
# 1.9921209586821552e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=4.177e-09, Variance=1.992e-05, Skewness=-43.52, Kurtosis=0.223
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      4.177e-09
# 1  Variance      1.992e-05
# 2  Skewness         -43.52
# 3  Kurtosis          0.223
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 19 ---
# Cosmological Parameters:
#   h=0.6893, Om=0.2166, Oc=0.1693, Ob=0.0473, sigma8=0.8636, w0=-0.9772, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3726.60 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.7539252864233834e-05
# Theoretical Map Variance (sigmasq_map): 1.754e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-887.04605061 -923.97797132 -941.72009495]
#   Critical points for z=0.0470500: [-887.04605061 -923.97797132 -941.72009495]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-319.90608727]
#   Critical points for z=0.0931000: [-319.90608727]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 531.99796162 -229.86998002]
#   Critical points for z=0.1391500: [ 531.99796162 -229.86998002]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 440.27536407 -248.97682605]
#   Critical points for z=0.1852000: [ 440.27536407 -248.97682605]
# Smallest positive value: 440.2753640736365
# Largest negative value: -229.8699800168746
# Smallest distance pair of critical points: 440.2753640736365 -229.8699800168746
# Computing PDF...
#   Using lambda range: [-229.87, 440.28]
# the coeffs are [-2.60554192e-07  4.22063465e-07  1.56833614e-06 -3.49843464e-06
#   4.76547154e-05 -1.63526883e-04  4.18812726e-03 -1.83964951e-08]
# 1.754040995526494e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=2.703e-07, Variance=1.753e-05, Skewness=-54.5, Kurtosis=0.2874
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      2.703e-07
# 1  Variance      1.753e-05
# 2  Skewness          -54.5
# 3  Kurtosis         0.2874
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 20 ---
# Cosmological Parameters:
#   h=0.6315, Om=0.3786, Oc=0.3313, Ob=0.0473, sigma8=0.7817, w0=-1.2463, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3375.45 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 2.0749125667134905e-05
# Theoretical Map Variance (sigmasq_map): 2.075e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-875.47112597]
#   Critical points for z=0.0470500: [-875.47112597]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-303.88145976]
#   Critical points for z=0.0931000: [-303.88145976]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 550.2081774  -207.28361591]
#   Critical points for z=0.1391500: [ 550.2081774  -207.28361591]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 408.73638539 -219.86035401]
#   Critical points for z=0.1852000: [ 408.73638539 -219.86035401]
# Smallest positive value: 408.73638539009556
# Largest negative value: -207.2836159102234
# Smallest distance pair of critical points: 408.73638539009556 -207.2836159102234
# Computing PDF...
#   Using lambda range: [-207.28, 408.74]
# the coeffs are [ 1.27419037e-07 -2.14740945e-07  8.83466112e-07 -4.28808773e-06
#   5.11455386e-05 -1.89759336e-04  4.55506363e-03  2.76028349e-09]
# 2.0748604638401466e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=3.787e-09, Variance=2.075e-05, Skewness=-54.87, Kurtosis=0.3526
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      3.787e-09
# 1  Variance      2.075e-05
# 2  Skewness         -54.87
# 3  Kurtosis         0.3526
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 21 ---
# Cosmological Parameters:
#   h=0.7981, Om=0.2076, Oc=0.1603, Ob=0.0473, sigma8=0.7700, w0=-0.8207, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3587.71 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.886637428909906e-05
# Theoretical Map Variance (sigmasq_map): 1.887e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [ -923.37666113  -944.86489941 -1046.88517487]
#   Critical points for z=0.0470500: [ -923.37666113  -944.86489941 -1046.88517487]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-360.2032397]
#   Critical points for z=0.0931000: [-360.2032397]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 594.10301012 -315.59986887]
#   Critical points for z=0.1391500: [ 594.10301012 -315.59986887]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 596.67751306 -349.33113334]
#   Critical points for z=0.1852000: [ 596.67751306 -349.33113334]
# Smallest positive value: 594.103010121047
# Largest negative value: -315.59986886687074
# Smallest distance pair of critical points: 594.103010121047 -315.59986886687074
# Computing PDF...
#   Using lambda range: [-315.60, 594.10]
# the coeffs are [ 1.39458131e-08 -6.46288109e-08  4.07382725e-07 -1.13284013e-06
#   3.20575667e-05 -1.32352897e-04  4.34355254e-03 -7.66866326e-10]
# 1.8866448708259336e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=-7.457e-10, Variance=1.887e-05, Skewness=-42.09, Kurtosis=0.2217
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean     -7.457e-10
# 1  Variance      1.887e-05
# 2  Skewness         -42.09
# 3  Kurtosis         0.2217
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 22 ---
# Cosmological Parameters:
#   h=0.6502, Om=0.3539, Oc=0.3066, Ob=0.0473, sigma8=0.6697, w0=-0.9257, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3284.75 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.2919384970736119e-05
# Theoretical Map Variance (sigmasq_map): 1.292e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-1223.84014018 -1321.20178451 -1330.68185458]
#   Critical points for z=0.0470500: [-1223.84014018 -1321.20178451 -1330.68185458]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-460.99879965]
#   Critical points for z=0.0931000: [-460.99879965]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 814.07013957 -322.88583564]
#   Critical points for z=0.1391500: [ 814.07013957 -322.88583564]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 618.75535803 -343.92555588]
#   Critical points for z=0.1852000: [ 618.75535803 -343.92555588]
# Smallest positive value: 618.7553580267228
# Largest negative value: -322.88583563624906
# Smallest distance pair of critical points: 618.7553580267228 -322.88583563624906
# Computing PDF...
#   Using lambda range: [-322.89, 618.76]
# Iteration 14.285714285714286 %
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:5: RuntimeWarning: invalid value encountered in power
#   return nu * (1. - rho**(-1./nu))
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:14: RuntimeWarning: invalid value encountered in sqrt
#   sig2lr12 = variance.nonlinear_sigma2(redshift=z, R1=chi*((1+delta1[:,newaxis])**0.5)* theta1,
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:15: RuntimeWarning: invalid value encountered in sqrt
#   R2=chi*((1+delta2[:,newaxis])**0.5)*theta2)
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:17: RuntimeWarning: invalid value encountered in sqrt
#   sig2lr11 = variance.nonlinear_sigma2(redshift=z, R1=chi*((1+delta1[:,newaxis])**0.5)*theta1,
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:18: RuntimeWarning: invalid value encountered in sqrt
#   R2=chi*((1+delta1[:,newaxis])**0.5)*theta1)
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:20: RuntimeWarning: invalid value encountered in sqrt
#   sig2lr22 = variance.nonlinear_sigma2(redshift=z, R1=chi*((1+delta2[:,newaxis])**0.5)*theta2,
# /feynman/work/dap/lcs/vt272285/final_codes/LDT_2cell_l1_norm/modules/ratefunction_module.py:21: RuntimeWarning: invalid value encountered in sqrt
#   R2=chi*((1+delta2[:,newaxis])**0.5)*theta2)
# the coeffs are [-0.0003167   0.00147366 -0.00061329 -0.00503147  0.00455146  0.00527032
#  -0.00197782 -0.003493  ]
# 3.911776122635673e-06
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=-0.003502, Variance=3.628e-06, Skewness=7183, Kurtosis=259.5
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      -0.003502
# 1  Variance      3.628e-06
# 2  Skewness           7183
# 3  Kurtosis          259.5
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 23 ---
# Cosmological Parameters:
#   h=0.7619, Om=0.2474, Oc=0.2001, Ob=0.0473, sigma8=0.7085, w0=-0.7408, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3388.36 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 1.568242495837035e-05
# Theoretical Map Variance (sigmasq_map): 1.568e-05
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  [-1157.71996155]
#   Critical points for z=0.0470500: [-1157.71996155]
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-421.12531529]
#   Critical points for z=0.0931000: [-421.12531529]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [ 695.92709075 -347.42829945]
#   Critical points for z=0.1391500: [ 695.92709075 -347.42829945]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [ 659.67303542 -388.1628529 ]
#   Critical points for z=0.1852000: [ 659.67303542 -388.1628529 ]
# Smallest positive value: 659.6730354194673
# Largest negative value: -347.4282994539102
# Smallest distance pair of critical points: 659.6730354194673 -347.4282994539102
# Computing PDF...
#   Using lambda range: [-347.43, 659.67]
# the coeffs are [-4.21412440e-08  8.27698504e-08  5.62786684e-07 -1.29568910e-06
#   2.70881773e-05 -1.21988483e-04  3.96036827e-03 -1.60426323e-08]
# 1.5684516828089553e-05
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=-2.025e-08, Variance=1.568e-05, Skewness=-46.69, Kurtosis=0.2107
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean     -2.025e-08
# 1  Variance      1.568e-05
# 2  Skewness         -46.69
# 3  Kurtosis         0.2107
# 4      Norm              1
# -----------------
#
# --- Running for Cosmology Index: 24 ---
# Cosmological Parameters:
#   h=0.6617, Om=0.2580, Oc=0.2107, Ob=0.0473, sigma8=0.6083, w0=-1.1488, wa=0.0000
# Initializing Cosmology...for iteration  0
# the min and max values of k are:  0.0001 1.5848931924611136 and length is:  200
# Calculating lensing geometry...
#   Source Redshift: 1.852, Comoving Distance: 3712.20 Mpc/h
#   Number of lensing planes: 7
# Initializing Variance and P(k)...
# Variance module initialized.e final z: 0.19
# Initializing VariablesGenerator...
# Calculating sigmasq_map...
# the shapes are:  (7,) (7,)
# VariablesGenerator Initialized:
#   Source Redshift (zs): 1.852
#   Angular Scale (theta1): 15.0 arcmin
#   Number of Planes: 7
#   Using n(z) file: True
#   Calculated Map Variance (sigmasq_map): 6.886503708086697e-06
# Theoretical Map Variance (sigmasq_map): 6.887e-06
# Recalibration Value Set To: 1.0
# Finding critical points...
# Setting ngrid = 120. Increase this for more accuracy, but note that computation becomes slower!
#   Redshift range for critical points: [0.001   0.04705 0.0931  0.13915 0.1852 ]
# The approximate critical points at redshift z:  0.001  are:  []
#   Critical points for z=0.0010000: []
# The approximate critical points at redshift z:  0.04705000000000001  are:  []
#   Critical points for z=0.0470500: []
# The approximate critical points at redshift z:  0.09310000000000002  are:  [-841.19152718]
#   Critical points for z=0.0931000: [-841.19152718]
# The approximate critical points at redshift z:  0.13915000000000002  are:  [-590.74307204]
#   Critical points for z=0.1391500: [-590.74307204]
# The approximate critical points at redshift z:  0.18520000000000003  are:  [-616.16855123]
#   Critical points for z=0.1852000: [-616.16855123]
# Smallest positive value: None
# Largest negative value: -590.7430720415352
# Smallest distance pair of critical points: None -590.7430720415352
# Computing PDF...
#   Warning: Using fallback lambda range.
# the coeffs are [-1.19132065e-09 -1.13284122e-09  7.94614778e-08 -3.49957740e-07
#   1.21025406e-05 -6.48079155e-05  2.62421487e-03  7.47601037e-14]
# 6.886503700796275e-06
# Calculating predicted L1 norm...
# Prediction PDF Moments: Mean=7.476e-14, Variance=6.887e-06, Skewness=-56.47, Kurtosis=0.14
#
# --- Comparison ---
#      Metric Prediction PDF
# 0      Mean      7.476e-14
# 1  Variance      6.887e-06
# 2  Skewness         -56.47
# 3  Kurtosis           0.14
# 4      Norm              1
# -----------------

# %%
# l1_prediction_list = np.array(l1_prediction_list)
# sigmasq_prediction_list = np.array(sigmasq_prediction_list)
# data = {
#     'l1_prediction_list': l1_prediction_list,
#     'sigmasq_prediction_list': sigmasq_prediction_list,
#     'kaappa_values': kappa_values,
# }

# np.save("l1_prediction_data_new_cosmos.npy", data)
